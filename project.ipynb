# %%
from pymongo import MongoClient

import os
from dotenv import find_dotenv, load_dotenv

# %%
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)

USERNAME = os.getenv("USER_NAME")
PASSWORD = os.getenv("PASSWORD")

# %% [markdown]
# The Following Code was used to upload all data to database (MongoDB Atlas)
# ``` python
# import json
#
# db = client.millionsongs_db
# collection = db.millionSongs
#
# # Load JSON file
# with open("millionSongs.json") as file:
#     file_data = json.load(file)
#
# # Insert JSON data into collection
# collection.insert_many(file_data)
# ```

# %%
connection_string = f"mongodb+srv://{USERNAME}:{PASSWORD}@mycluster.48lmugl.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(connection_string)

# %%
list(client.list_databases())
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\Users\Mahesh Ghorsaine\OneDrive\Data_Engineering\SparkyfyProject\project.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mahesh%20Ghorsaine/OneDrive/Data_Engineering/SparkyfyProject/project.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> list(client.list_databases())
#
# File c:\Users\Mahesh Ghorsaine\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\mongo_client.py:1840, in MongoClient.list_databases(self, session, comment, **kwargs)
#    1838     cmd["comment"] = comment
#    1839 admin = self._database_default_options("admin")
# -> 1840 res = admin._retryable_read_command(cmd, session=session)
#    1841 # listDatabases doesn't return a cursor (yet). Fake one.
#    1842 cursor = {
#    1843     "id": 0,
#    1844     "firstBatch": res["databases"],
#    1845     "ns": "admin.$cmd",
#    1846 }
#
# ...

# %%
db = client["millionsongs_db"]

# %%
list(db.list_collections())
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\Users\Mahesh Ghorsaine\OneDrive\Data_Engineering\SparkyfyProject\project.ipynb Cell 7 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mahesh%20Ghorsaine/OneDrive/Data_Engineering/SparkyfyProject/project.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> list(db.list_collections())
#
# File c:\Users\Mahesh Ghorsaine\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\database.py:911, in Database.list_collections(self, session, filter, comment, **kwargs)
#     906 def _cmd(session, server, sock_info, read_preference):
#     907     return self._list_collections(
#     908         sock_info, session, read_preference=read_preference, **kwargs
#     909     )
# --> 911 return self.__client._retryable_read(_cmd, read_pref, session)
#
# ...

# %%
for c in db.list_collections():
    print(c["name"])
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\Users\Mahesh Ghorsaine\OneDrive\Data_Engineering\SparkyfyProject\project.ipynb Cell 8 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mahesh%20Ghorsaine/OneDrive/Data_Engineering/SparkyfyProject/project.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> for c in db.list_collections():
#       <a href='vscode-notebook-cell:/c%3A/Users/Mahesh%20Ghorsaine/OneDrive/Data_Engineering/SparkyfyProject/project.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>     print(c["name"])
#
# File c:\Users\Mahesh Ghorsaine\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\database.py:911, in Database.list_collections(self, session, filter, comment, **kwargs)
#     906 def _cmd(session, server, sock_info, read_preference):
#     907     return self._list_collections(
#     908         sock_info, session, read_preference=read_preference, **kwargs
# ...

# %%
million_songs = db["millionSongs"]

# %%
million_songs.count_documents({})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\Users\Mahesh Ghorsaine\OneDrive\Data_Engineering\SparkyfyProject\project.ipynb Cell 10 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mahesh%20Ghorsaine/OneDrive/Data_Engineering/SparkyfyProject/project.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> million_songs.count_documents({})
#
# File c:\Users\Mahesh Ghorsaine\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py:1842, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    1839         return 0
#    1840     return result["n"]
# -> 1842 return self._retryable_non_cursor_read(_cmd, session)
#
# File c:\Users\Mahesh Ghorsaine\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py:1848, in Collection._retryable_non_cursor_read(self, func, session)
#    1846 client = self.__database.client
# ...

# %%
million_songs.find_one({})
# Out:
# {'_id': ObjectId('641a9b5063a82d799bb29818'),
#  'ts': 1538352011000,
#  'userId': '293',
#  'sessionId': 292,
#  'page': 'NextSong',
#  'auth': 'Logged In',
#  'method': 'PUT',
#  'status': 200,
#  'level': 'free',
#  'itemInSession': 20,
#  'location': 'Corpus Christi, TX',
#  'userAgent': '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#  'lastName': 'Morales',
#  'firstName': 'Joseph',
#  'registration': 1532063507000,
#  'gender': 'M',
#  'artist': 'Martin Orford',
#  'song': 'Grand Designs',
#  'length': 597.55057}
